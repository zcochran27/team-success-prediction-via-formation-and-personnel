# %% [markdown]
# # Cross-Model Results
#
# Final 8-way comparison: 4 models x 2 targets.
#
# Sections:
# - Aggregate metric table (MAE, RMSE, R^2) per model and target.
# - Pairwise gains: archetypes vs. positions (1 vs 2, 3 vs 4) and
#   graph vs. tabular (1 vs 3, 2 vs 4); combined gain (1 vs 4).
# - Per-fold variance plots.
# - Error analysis on the worst-predicted team-seasons.

# %%
# TODO: load CV results for all four models and build the comparison table.
