# %% [markdown]
# # Exploratory Data Analysis
#
# Dataset overview for the NCAA Division I Wyscout event data.
#
# Goals:
# - Distributions of win rate and points per game across team-seasons.
# - Formation frequencies (overall and by conference / season).
# - Event volume by position group and event type.
# - Roster / lineup stability across the season (informs use of the modal lineup).

# %%
# TODO: load raw + team_seasons data and produce overview statistics.
