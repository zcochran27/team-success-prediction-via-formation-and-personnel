# %% [markdown]
# # Graph Comparison Across Formations
#
# Compare graph topology across formations (4-3-3, 4-2-3-1, 3-5-2, ...).
#
# Goals:
# - Side-by-side renders of each formation's canonical graph.
# - Tabulate edge counts and degree distributions.
# - Surface any formations missing from `FORMATION_EDGE_RULES`.

# %%
# TODO: load all registered formations and compare topology side-by-side.
