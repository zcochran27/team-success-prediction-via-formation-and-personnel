# %% [markdown]
# # Graph Construction
#
# Visualize sample team-season graphs produced by `features.build_graphs`
# and verify the formation-specific edge logic.
#
# Goals:
# - For each supported formation, draw the canonical edge layout.
# - Confirm intra-line edges (DEF/MID/ATT) and cross-line edges (e.g. CM-ST, FB-W).
# - Spot-check a small batch of real team-season graphs.

# %%
# TODO: build sample graphs and render with networkx + matplotlib.
